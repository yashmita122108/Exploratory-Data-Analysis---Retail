# %% [markdown]
# # Graduate Rotational Internship Program

# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Task -3: Exploratory Data Analysis - Retail

# %% [markdown]
# # Author : Yashmita

# %% [markdown]
# **Problem statement**
#
# Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# As a business manager, try to find out the weak areas where you can work to make more profit.
#
# What all business problems you can derive by exploring the data?

# %% [markdown]
# **Dataset**: https:/bit.ly/3i4rbWI

# %% [markdown]
# # Step 1 : Import the required libraries

# %%
# !pip install --upgrade matplotlib
# !pip uninstall matplotlib
# !pip install matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\hp\\anaconda3\\Lib\\site-packages\\matplotlib\\_c_internal_utils.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
#   Using cached matplotlib-3.8.0-cp39-cp39-win_amd64.whl (7.6 MB)
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# ...

# %%
### Import all necessary Libraries
import numpy as np
import pandas as pd
import seaborn as sns
from plotnine import *
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2 : Extract data from source

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
#Checking for the dimension of the dataset
df.shape
# Out:
# (9994, 13)

# %%
# Checking for the datatypes
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
for i in df.columns:
    print(i,len(df[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5825
# Quantity 14
# Discount 12
# Profit 7287

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# checking for duplicate values
df.duplicated().sum()
# Out:
# 17

# %%
# Dropping those duplicate values
df.drop_duplicates()
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Removing the unnecessary columns such as postal code
df = df.drop(['Postal Code'],axis=1)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Performing - Exploratory Data Analysis

# %% [markdown]
# # Step 3 : Data Visualization

# %% [markdown]
# **Category vs Sub Category Analysis**

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=df)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The bar chart illustrates how different sub-categories are distributed across various categories within the dataset. Each bar in the chart represents a sub-category, and the height of the bar indicates the corresponding category.
#
# The x-axis shows the "Sub-Category," which represents specific items or products within a broader category.
# The y-axis represents the "Category," which represents the broader classification or grouping of those items or products.
# From the chart it is observed that the data is not normal.Under sub-categories phone, accesories, machines, copiers are highest amoung the all 3 categories.Other subcategories are efficient for office supplies.

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# **Statewise Analysis**

# %%
# Count the total repeatable states
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.title("STATE")
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The countplot displays the frequency of occurrences of each unique value in the "State" column of the dataset. It provides insight into how data points are distributed across different states.It can be infered that,the top three states with the highest deal volumes are California, New York, and Texas.

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))
sns.barplot(x='Sub-Category',y='Profit', data=df, palette='Spectral')
plt.suptitle('Pie Consumption Patterns in the United States', fontsize=16)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The bar plot displays the profitability (profits) associated with different sub-categories of products or items. Each bar represents a specific sub-category, and the height of the bar corresponds to the profit generated by that sub-category.
#
# One sub-category stands out for its exceptional profit performance, having maintained a flawless record with no losses. Meanwhile, several other sub-categories remained profitable without encountering losses, albeit with comparatively lower profit margins. On the opposite end of the spectrum, the "Machines" sub-category endured the most significant losses among all.

# %%
figsize=(15,10)
sns.pairplot(df,hue='Sub-Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **INFERENCE**
#
# The provided code generates a pairplot using Seaborn to visualize the relationships between different pairs of numerical variables in a dataset represented by the variable df, while color-coding the data points by the "Sub-Category."
# The pairplot allows for a comprehensive exploration of the dataset's numerical variables while considering the "Sub-Category" as a categorical variable for color differentiation.
#
# Based on the plot displayed above, we can conclude that our data does not exhibit a normal distribution and contains noticeable outliers.

# %%
# Finding the pairwise correlations between the columns and visualising using heatmaps
# correlation matrix and heatmap
#Heatmaps are useful to visualize the magnitude of relationship between multiple  variables usig the coreelation matrix.
#Pairs which show high correlation, <-0.75 or >0.75, should be considered and we can eliminate one variable out of the pair leading to fetaure selection.
#value close to 1-->high positive correlation
#value close to -1-->high negative correlation
#value close to 0-->no correlation
df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The code generates a heatmap that visually represents the correlation matrix of the dataset's numerical columns.It is observed that,
#
# There is a moderate positive correlation between sales and profit, indicating that as sales increase, profits tend to rise moderately. Conversely, profit and discount are negatively correlated, suggesting that higher discounts may lead to lower profits. Quantity and profit demonstrate a somewhat weaker positive correlation, implying that an increase in the quantity of items sold is associated with a moderate increase in profits, though the relationship is not as strong as with sales.

# %% [markdown]
# Now, let's examine the sales patterns in selected states from different profit categories, including high profit, medium profit, low profit, low loss, and high loss. Our goal is to identify key trends that can potentially boost sales. We aim to answer the following questions:
#
# What are the preferred products among states that generate the highest profits?
# Which products are commonly purchased in states that incur losses?
# Which product segments require enhancement to elevate overall profits?

# %%
state_code = {'Alabama': 'AL','Alaska': 'AK','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO','Connecticut': 'CT','Delaware': 'DE','Florida': 'FL','Georgia': 'GA','Hawaii': 'HI','Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY','Louisiana': 'LA','Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN','Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC','North Dakota': 'ND','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Rhode Island': 'RI','South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT','Vermont': 'VT','Virginia': 'VA','District of Columbia': 'WA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY'}
df['state_code'] = df.State.apply(lambda x: state_code[x])

# %%
def state_data_viewer(states):
    """Plots the turnover generated by different product categories and sub-categories for the list of given states.
    Args:
        states- List of all the states you want the plots for
    Returns:
        None
    """
    product_data = df.groupby(['State'])
    for state in states:
        data = product_data.get_group(state).groupby(['Category'])
        fig, ax = plt.subplots(1, 3, figsize = (28,5))
        fig.suptitle(state, fontsize=14)        
        ax_index = 0
        for cat in ['Furniture', 'Office Supplies', 'Technology']:
            cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
            sns.barplot(x = cat_data.Profit, y = cat_data.index, ax = ax[ax_index])
            ax[ax_index].set_ylabel(cat)
            ax_index +=1
        fig.show()

# %%
states = ['California', 'Washington', 'Mississippi', 'Arizona', 'Texas']
state_data_viewer(states)

# %% [markdown]
# **INFERENCE**
#
# This function state_data_viewer that generates visualizations to analyze turnover (or sales) for different product categories and sub-categories within a given list of states, focusing on three main product categories: Furniture, Office Supplies, and Technology. It aims to provide insights into the profitability of various sub-categories within these product categories with State-Specific Analysis,Category & sub categoryBreakdown
#
# Bar plots are used to visualize the profits of sub-categories, with sub-categories listed on the y-axis and profit on the x-axis. This format allows for easy comparison of profitability among sub-categories.

# %% [markdown]
# **Count plot of each column -  categorical data's distribution**

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)


plt.tight_layout()

# %% [markdown]
# **INFERENCE**
#
# The first plot visualizes the distribution of products across different categories where office supplies categories are high.
# The second plot shows the distribution of segments or customer types where consumer segment is high.
# The third plot displays the distribution of shipping modes where standard class are high.
# The fourth plot presents the distribution of data across various regions where west region is high.
#
# This visual arrangement allows for a quick assessment of the categorical data's distribution and can reveal patterns or imbalances within these categories. It's a useful initial step for understanding the characteristics of the dataset and can inform further analysis and decision-making.

# %% [markdown]
# **Quantity wise Analysis**

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Quantity'])
plt.title('Quantity',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quantity')

# %% [markdown]
# **INFERENCE**
#
# The countplot allows us to understand the distribution of quantities within the dataset. Each bar in the plot represents a unique quantity value, and the height of the bar corresponds to the number of occurrences of that quantity.
#
# By examining this plot, it can be identified that the most common quantity values, as well as any outliers or unusual patterns in the data. This information can be valuable for understanding purchasing or order quantity trends within the dataset.

# %% [markdown]
# **Discount Analysis**

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# **INFERENCE**
#
# The countplot allows us to understand the distribution of discounts within the dataset. Each bar in the plot represents a unique discount value, and the height of the bar corresponds to the number of occurrences of that discount.
# The rotation of x-axis labels ensures that lengthy discount values can be read more easily.
#
# By examining this plot, you can quickly identify the most common discount values and the frequency at which each discount is applied. This information can be valuable for assessing pricing strategies, promotional efforts, and the impact of discounts on sales or profits.

# %% [markdown]
#  **Visualizing the data distribution for each variable**

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (10,10))
sns.distplot(df['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(df['Profit'], color = 'green',  ax = axs[0][1])
sns.distplot(df['Quantity'], color = 'orange',  ax = axs[1][0])
sns.distplot(df['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The distribution plots allow us to examine the data distribution for each variable. They provide insights into the central tendency, spread, and shape of the data.
#
# "Sales Distribution" visualizes how sales values are distributed, showing whether they follow a particular pattern or are skewed.
#
# "Profit Distribution" provides a view of the profit values' distribution, helping identify potential profit patterns or outliers.
#
# "Quantity Distribution" displays the distribution of quantity values, indicating how often certain quantities appear in the dataset.
#
# "Discount Distribution" shows the distribution of discount values and helps in understanding the frequency of discounts applied.
#
# These distribution plots are essential for understanding the characteristics of the dataset and can inform further analysis, such as identifying potential outliers or assessing the normality of the data.

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df_segment= df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
#Visualising the categories
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
plt.title('Category')
plt.pie(df['Category'].value_counts(), labels=df['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The pie chart visually conveys the composition of the dataset across various categories. Each slice represents a category, and its size reflects the proportion of data points in that category relative to the whole dataset.
#
# By looking at the chart, you can quickly discern which categories dominate the dataset and which ones have smaller shares. This information is helpful for understanding the distribution of data among different categories and can guide decision-making or further analysis related to these categorieswhere Technology makes 18.5% , Furniture makes 21.2%, office supplies make 60.3% distribution.

# %%
# Bar plot of the category of Profit VS Sales
plt.figure(figsize= (10,16))
df.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# **INFERENCE**
#
# Product categories with higher bars in the "Profit" section are more profitable, while those with taller bars in the "Sales" section have higher sales volumes.This visualization helps in assessing the relationship between sales and profit across different product categories. It can be valuable for identifying categories that are both high in sales and profitability or those that may require attention to improve profitability despite high sales.

# %% [markdown]
# **The profit and loss in the dataset with the Sub Categories**

# %%
# Checking the profit and loss in the dataset with the Sub Categories
fig,axes = plt.subplots(1,2,figsize=(13,5))
fig.suptitle("Total profit VS sales ")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Profit'].agg(sum),x='Sales',y='Profit',ax=axes[1])
df.groupby('Sub-Category')['Sales','Profit'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The left bar plot provides a direct comparison between the total sales and total profit for each sub-category. It allows for easy identification of sub-categories that are both high in sales and profitability and those that may be underperforming.
#
# The right scatter plot shows how sales and profit are related for each sub-category. Points above the line indicate sub-categories where profit exceeds sales, while points below the line indicate sub-categories with higher sales but lower profits.
#
# These visualizations are valuable for identifying sub-categories that may require attention, whether to maximize profitability or to optimize sales strategies. They can guide decision-making in terms of product offerings and pricing adjustments.

# %%
#Visualising the discount
plt.figure(figsize=(8,7))
sns.lineplot(df['Discount'], df['Profit'], data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
# Comparing with distplot
fig,axes = plt.subplots(2,2,figsize=(16,8))
fig.suptitle("Distribution plots", fontsize=16)
sns.distplot(df['Sales'],ax=axes[0,0])
sns.distplot(df['Profit'],ax=axes[0,1])
sns.distplot(df['Discount'],ax=axes[1,0])
sns.distplot(df['Quantity'],ax=axes[1,1])
plt.show()

# %% [markdown]
# **INFERENCE**
#
# Sales Distribution: The first plot (top-left) shows the distribution of sales values. It provides insights into the spread and shape of the sales data, helping identify central tendencies and potential outliers.
#
# Profit Distribution: The second plot (top-right) visualizes the distribution of profit values. It helps assess how profits are distributed across the dataset and whether there are profit patterns or anomalies.
#
# Discount Distribution: The third plot (bottom-left) displays the distribution of discount values. It reveals how frequently different discount levels are applied and whether there are common discount ranges.
#
# Quantity Distribution: The fourth plot (bottom-right) illustrates the distribution of quantity values. It provides information on how often different quantities are ordered, which can be important for inventory management and sales forecasting.

# %% [markdown]
# **Analysis using Pairplot of each column - Based on the Category**

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# **Analysis using Pairplot of each column - Based on Region**

# %%
sns.pairplot(df,hue='Region')

# %% [markdown]
# **Visualizing the Sales vs Profits in different Regions & states**

# %%
#Visualizing the Sales vs Profits in different Regions
plt.figure(figsize = (6,6))
plt.title('Region')
plt.pie(df['Region'].value_counts(), labels=df['Region'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **INFERENCE**
#
# The pie chart visually conveys the composition of the dataset across various regions. Each slice represents a region, and its size indicates the proportion of data points in that region.
#
# By examining the chart, you can quickly discern which regions have the largest and smallest shares of the dataset. This information can be useful for understanding the geographical distribution of data and making regional comparisons. While this chart provides an overview of the data distribution by region, further analysis and visualizations may be needed to explore how sales, profits, or other variables vary across these regions.

# %%
#Visualising the Sales vs Profits in different states
# computing top states in terms of sales from first 10 observations
top_states = df.groupby("State").Sales.sum().nlargest(n=10)

# computing top states in terms of profit from first 10 observations
top_states_p = df.groupby("State").Profit.sum().nlargest(n = 10)

plt.style.use('seaborn')
top_states.plot(kind = 'bar',figsize = (10,5),fontsize = 14)
top_states_p.plot(kind = 'bar',figsize = (10,5),fontsize = 14, color = 'red')
plt.xlabel('States',fontsize = 15)
plt.ylabel('Total sales',fontsize = 15)
plt.title("Top 10 states Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# This two bar plots side by side, comparing the total sales and total profits for the top 10 states with the highest values in each category. The states are listed on the x-axis, and the corresponding sales and profits are represented by bars on the y-axis. The code helps visualize the relationship between sales and profits in these states.

# %%
#Checking the interdependency of Sales,Profits and Discounts
plt.style.use('seaborn')
df.plot(kind = "scatter",figsize = (10,5), x = "Sales", y= "Profit", c = "Discount", s = 15,fontsize = 16, colormap = 'Dark2_r')
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Interdependency of Sales,Profits and Discounts",fontsize = 16)

plt.show()

# %% [markdown]
# **INFERENCE**
#
# Through the data visualization and clustering analysis mentioned earlier, we can identify the states and product categories where both sales and profits are either high or low. This insight can guide us in enhancing performance in those states by offering discounts within a specified range. By doing so, we can ensure that both the company and consumers benefit, leading to increased profitability.

# %% [markdown]
# **TASK END NOTE**
#
# It's important to highlight that even though the superstore is facing losses as a result of offering discounts on its products, discontinuing these discounts is not a viable option. The majority of these significant discounts occur during festivals, end-of-season sales, and clearance events, which serve the crucial purpose of creating space in the store's warehouses for new stock. Additionally, while the company may experience modest losses from these discounts in the short term, it ultimately reaps the benefits by attracting more long-term customers. Therefore, the minor losses incurred from discounting are an integral and necessary aspect of the company's business strategy.
